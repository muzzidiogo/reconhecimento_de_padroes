# %% [markdown]
# # Regra de Bayes

# %% [markdown]
# ## Caso 1D

# %%
import numpy as np
from matplotlib import pyplot as plt
from utils import gen_1D_gaussians, plot_1D_gaussians

X = np.linspace(0, 6, 100)
Y1 = gen_1D_gaussians(X, s=0.5, c=2)
Y2 = gen_1D_gaussians(X, s=0.5, c=4)
plt.plot(X, Y1, label = 'Class 1', color = 'blue')
plt.plot(X, Y2, label = 'Class 2', color = 'red')
plt.xlim(0, 6)
plt.ylim(0, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 9
#       7 Y2 = gen_1D_gaussians(X, s=0.5, c=4)
#       8 plt.plot(X, Y1, label = 'Class 1', color = 'blue')
# ----> 9 plt.scatter(X)
#      10 plt.plot(X, Y2, label = 'Class 2', color = 'red')
#      11 plt.xlim(0, 6)
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %% [markdown]
# ## Caso 2D

# %%
from utils import gen_2D_gaussians
X, Y = gen_2D_gaussians()
plt.scatter(X[:100, 0], X[:100, 1], c='b', label='Class 1')
plt.scatter(X[100:, 0], X[100:, 1], c='r', label='Class -1')

# %% [markdown]
# ## Superfície
